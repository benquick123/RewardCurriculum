# %%
import sys
sys.path.append("..")

import matplotlib.font_manager as font_manager
import matplotlib as mpl
from matplotlib import pyplot as plt
import numpy as np
import os
from copy import copy

font_dir = ['.']
for font in font_manager.findSystemFonts(font_dir):
    font_manager.fontManager.addfont(font)
plt.rcParams['font.family'] = ['EBGaramond']

# %%
text_width = 295.8252 # pt
dpi = plt.rcParams['figure.dpi']
latex_dpi = 72
cmap = copy(plt.get_cmap("magma"))
cmap.set_bad(color="gray")
colors = mpl.colormaps['Dark2'].resampled(7)
scale = 2.5
savefig_kwargs = {
    'bbox_inches': 'tight',
    'pad_inches': 0.01,
}
figures_path = "../results/Figures-v3"

# %%
import pickle
def pickleable(obj):
    try:
        pickle.dumps(obj)
    except (TypeError, AttributeError, KeyError):
        return False
    return True

# with open(os.path.join("/tmp", "plotting_session.pkl"), "wb") as session_file:
#     session_object = {key: value for key, value in locals().items() if not key.startswith("_") and not callable(value) and pickleable(value)}
#     pickle.dump(session_object, session_file)
